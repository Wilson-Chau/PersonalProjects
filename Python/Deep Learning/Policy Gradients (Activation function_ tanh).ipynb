# %% [markdown]
# # Policy Gradients: REINFORCE Baseline with LunarLander

# %%
# Install dependencies
# !sudo apt-get update > /dev/null 2>&1
# !sudo apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install rarfile --quiet
# !pip install stable-baselines3[extra] ale-py==0.7.4 --quiet
# !pip install box2d-py --quiet
# !pip install gym pyvirtualdisplay --quiet
# !pip install pyglet --quiet

# %%
import io
import os
import glob

import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np

import gym
from gym import spaces
from gym.wrappers import Monitor

# %%
# check and use GPU if available if not use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### LunarLander
#
# LunarLander is an OpenAI gym environment (env). In this env the agent tries to land a space craft safely on the ground by firing the main, left, or right engine. The agent receives a reward for navigating to the landing pad and turning off the engine, a large reward for a safe landing, a large negative reward for an unsafe landing, and a small negative reward for using the engines. There are discrete and continuous versions of LunarLander.

# %%
# @title Plotting/Video functions
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

display = Display(visible=0, size=(1400, 900))
display.start()

"""
Utility functions to enable video recording of gym environment
and displaying it.
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else:
    print("Could not find video")


def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
env = gym.make('LunarLander-v2')
env.reset()

prev_screen = env.render(mode='rgb_array')
plt.imshow(prev_screen)

for i in range(200):
    env.render()
    action = env.action_space.sample()
    obs, reward, done, info = env.step(action)
    if done:
        env.reset()
        
env.close()

# %% [markdown]
# ### Policy Gradient Methods
#
# In policy gradient methods, we update the policy directly. Ie we parameterize the policy and perform gradient descent updates on the policy parameters seeking to improve the policy. This is in contrast to section 3 where we learned estimates of the state or action-values. Then we extracted a policy based on those values, like with the epsilon greedy DQN policy.
#
# ### Discrete vs. Continuous Action Spaces
#
# PG methods can work in discrete and continuous action spaces. The DQN method we went over in section three required discrete action spaces: ie a limited number of actions. In continuous actions spaces there are an infinite number of actions as the action can be any value in a range. Continuous action spaces are often parameterized by a probability distribution and we learn the parameters of the distribution. For example we assume the actions come from a Gaussian distribution and try to learn the mean and standard deviation of the Gaussian that leads to the best policy.
#
# ### REINFORCE with Lunar Lander
#
# In this example, we will solve the discrete version of Lunar Lander using the REINFORCE with baseline method.

# %%
class ActorNet(nn.Module):
    def __init__(self, state_size, action_size, hidden_size):
        super(ActorNet, self).__init__()
        self.dense_layer_1 = nn.Linear(state_size, hidden_size)
        self.dense_layer_2 = nn.Linear(hidden_size, hidden_size)
        self.output = nn.Linear(hidden_size, action_size)
    
    def forward(self, x):
        x = torch.clamp(x,-1.1,1.1)
        x = F.tanh(self.dense_layer_1(x))
        x = F.tanh(self.dense_layer_2(x))
        return F.softmax(self.output(x),dim=-1) #-1 to take softmax of last dimension
    
class ValueFunctionNet(nn.Module):
    def __init__(self, state_size, hidden_size):
        super(ValueFunctionNet, self).__init__()
        self.dense_layer_1 = nn.Linear(state_size, hidden_size)
        self.dense_layer_2 = nn.Linear(hidden_size, hidden_size)
        self.output = nn.Linear(hidden_size, 1)
    
    def forward(self, x):
        x = torch.clamp(x,-1.1,1.1)
        x = F.tanh(self.dense_layer_1(x))
        x = F.tanh(self.dense_layer_2(x))
        return self.output(x)

# %%
class PGAgent():
    def __init__(self, state_size, action_size, hidden_size, actor_lr, vf_lr, discount ):
        self.action_size = action_size
        self.actor_net = ActorNet(state_size, action_size, hidden_size).to(device)
        self.vf_net = ValueFunctionNet(state_size, hidden_size).to(device)
        self.actor_optimizer = optim.Adam(self.actor_net.parameters(), lr=actor_lr)
        self.vf_optimizer = optim.Adam(self.vf_net.parameters(), lr=vf_lr)
        self.discount = discount
        
    def select_action(self, state):
        #get action probs then randomly sample from the probabilities
        with torch.no_grad():
            input_state = torch.FloatTensor(state).to(device)
            action_probs = self.actor_net(input_state)
            #detach and turn to numpy to use with np.random.choice()
            action_probs = action_probs.detach().cpu().numpy()
            action = np.random.choice(np.arange(self.action_size), p=action_probs)
        return action

    def train(self, state_list, action_list, reward_list):
        
        #turn rewards into return
        trajectory_len = len(reward_list)
        return_array = np.zeros((trajectory_len,))
        g_return = 0.
        for i in range(trajectory_len-1,-1,-1):
            g_return = reward_list[i] + self.discount*g_return
            return_array[i] = g_return
            
        # create tensors
        state_t = torch.FloatTensor(state_list).to(device)
        action_t = torch.LongTensor(action_list).to(device).view(-1,1)
        return_t = torch.FloatTensor(return_array).to(device).view(-1,1)
        
        # get value function estimates
        vf_t = self.vf_net(state_t).to(device)
        with torch.no_grad():
            advantage_t = return_t - vf_t
        
        # calculate actor loss
        selected_action_prob = self.actor_net(state_t).gather(1, action_t)
        # REINFORCE loss:
        #actor_loss = torch.mean(-torch.log(selected_action_prob) * return_t)
        # REINFORCE Baseline loss:
        actor_loss = torch.mean(-torch.log(selected_action_prob) * advantage_t)
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step() 

        # calculate vf loss
        loss_fn = nn.MSELoss()
        vf_loss = loss_fn(vf_t, return_t)
        self.vf_optimizer.zero_grad()
        vf_loss.backward()
        self.vf_optimizer.step() 
        
        return actor_loss.detach().cpu().numpy(), vf_loss.detach().cpu().numpy()

# %%
# initialize environment
env = gym.make('LunarLander-v2')
action_size = env.action_space.n
state_size = env.observation_space.shape[0]

# set seed
seed = 31
env.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# hyperparameters
episodes = 5000 # run agent for this many episodes
hidden_size = 128 # number of units in NN hidden layers
actor_lr = 0.001 # learning rate for actor
value_function_lr = 0.001 # learning rate for value function
discount = 0.99 # discount factor gamma value
reward_scale = 0.01 #scale reward by this amount

# create agent
agent = PGAgent(state_size, action_size, hidden_size, actor_lr, value_function_lr, discount)

# %%
stats_rewards_list = [] # store stats for plotting in this
stats_every = 10 # print stats every this many episodes
total_reward = 0
timesteps = 0
episode_length = 0
stats_actor_loss, stats_vf_loss = 0., 0.

for ep in range(episodes):
    state = env.reset()
    state_list, action_list, reward_list = [], [], []
    
    # stopping condition for training if agent reaches the amount of reward
    if len(stats_rewards_list) > stats_every and np.mean(stats_rewards_list[-stats_every:],axis=0)[1] > 190:
        print("Stopping at episode {} with average rewards of {} in last {} episodes".
            format(ep, np.mean(stats_rewards_list[-stats_every:],axis=0)[1], stats_every))
        break  

    # train in each episode until episode is done
    while True:
        timesteps += 1
        #env.render()
        # select an action from the agent's policy
        action = agent.select_action(state)
        
        # enter action into the env
        next_state, reward, done, _ = env.step(action)
        total_reward += reward
        episode_length += 1
        # store agent's trajectory
        state_list.append(state)
        action_list.append(action)
        reward_list.append(reward*reward_scale)
        
        # end episode early
        if total_reward < -250:
            done = 1
        
        if done:
            actor_loss, vf_loss = agent.train(state_list, action_list, reward_list)
            stats_rewards_list.append((ep, total_reward, episode_length))
            stats_actor_loss += actor_loss
            stats_vf_loss += vf_loss
            total_reward = 0
            episode_length = 0  
            if ep % stats_every == 0:
                print('Episode: {}'.format(ep),
                    'Timestep: {}'.format(timesteps),
                    'Total reward: {:.1f}'.format(np.mean(stats_rewards_list[-stats_every:],axis=0)[1]),
                    'Episode length: {:.1f}'.format(np.mean(stats_rewards_list[-stats_every:],axis=0)[2]),
                    'Actor Loss: {:.4f}'.format(stats_actor_loss/stats_every), 
                    'VF Loss: {:.4f}'.format(stats_vf_loss/stats_every))
                stats_actor_loss, stats_vf_loss = 0., 0.
            break
        
        state = next_state
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1949: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode: 0 Timestep: 59 Total reward: -63.9 Episode length: 59.0 Actor Loss: -0.0482 VF Loss: 0.0164
# Episode: 10 Timestep: 959 Total reward: -238.8 Episode length: 90.0 Actor Loss: -0.4882 VF Loss: 0.5542
# Episode: 20 Timestep: 2026 Total reward: -261.6 Episode length: 106.7 Actor Loss: 0.2231 VF Loss: 0.2266
# Episode: 30 Timestep: 2938 Total reward: -244.3 Episode length: 91.2 Actor Loss: 0.0638 VF Loss: 0.2493
# Episode: 40 Timestep: 3951 Total reward: -233.3 Episode length: 101.3 Actor Loss: -0.0739 VF Loss: 0.2671
# Episode: 50 Timestep: 5101 Total reward: -261.6 Episode length: 115.0 Actor Loss: -0.0677 VF Loss: 0.1984
# Episode: 60 Timestep: 6011 Total reward: -262.7 Episode length: 91.0 Actor Loss: 0.0050 VF Loss: 0.1818
# Episode: 70 Timestep: 6896 Total reward: -260.3 Episode length: 88.5 Actor Loss: -0.0139 VF Loss: 0.2070
# Episode: 80 Timestep: 7951 Total reward: -265.1 Episode length: 105.5 Actor Loss: -0.0102 VF Loss: 0.1804
# Episode: 90 Timestep: 9087 Total reward: -243.8 Episode length: 113.6 Actor Loss: 0.1147 VF Loss: 0.3100
# Episode: 100 Timestep: 10240 Total reward: -231.5 Episode length: 115.3 Actor Loss: 0.0591 VF Loss: 0.3691
# Episode: 110 Timestep: 11496 Total reward: -199.8 Episode length: 125.6 Actor Loss: 0.0577 VF Loss: 0.2701
# Episode: 120 Timestep: 12721 Total reward: -240.8 Episode length: 122.5 Actor Loss: -0.2148 VF Loss: 0.3404
# Episode: 130 Timestep: 13941 Total reward: -210.0 Episode length: 122.0 Actor Loss: 0.1750 VF Loss: 0.4350
# Episode: 140 Timestep: 15158 Total reward: -242.0 Episode length: 121.7 Actor Loss: -0.0370 VF Loss: 0.2241
# Episode: 150 Timestep: 16635 Total reward: -258.6 Episode length: 147.7 Actor Loss: 0.0001 VF Loss: 0.1080
# Episode: 160 Timestep: 18138 Total reward: -261.4 Episode length: 150.3 Actor Loss: 0.0121 VF Loss: 0.1819
# Episode: 170 Timestep: 19668 Total reward: -158.6 Episode length: 153.0 Actor Loss: 0.1636 VF Loss: 0.3703
# Episode: 180 Timestep: 21016 Total reward: -111.0 Episode length: 134.8 Actor Loss: 0.0525 VF Loss: 0.1740
# Episode: 190 Timestep: 22217 Total reward: -82.5 Episode length: 120.1 Actor Loss: -0.0549 VF Loss: 0.1503
# Episode: 200 Timestep: 23225 Total reward: -86.5 Episode length: 100.8 Actor Loss: -0.1736 VF Loss: 0.1223
# Episode: 210 Timestep: 24321 Total reward: -61.3 Episode length: 109.6 Actor Loss: 0.1449 VF Loss: 0.1288
# Episode: 220 Timestep: 25643 Total reward: -95.0 Episode length: 132.2 Actor Loss: -0.1245 VF Loss: 0.0565
# Episode: 230 Timestep: 27236 Total reward: -119.1 Episode length: 159.3 Actor Loss: -0.1497 VF Loss: 0.1816
# Episode: 240 Timestep: 28768 Total reward: -132.0 Episode length: 153.2 Actor Loss: -0.0725 VF Loss: 0.3214
# Episode: 250 Timestep: 30183 Total reward: -138.3 Episode length: 141.5 Actor Loss: 0.1199 VF Loss: 0.2181
# Episode: 260 Timestep: 31961 Total reward: -85.7 Episode length: 177.8 Actor Loss: 0.3708 VF Loss: 0.2566
# Episode: 270 Timestep: 33260 Total reward: -74.1 Episode length: 129.9 Actor Loss: -0.2970 VF Loss: 0.1745
# Episode: 280 Timestep: 34559 Total reward: -31.4 Episode length: 129.9 Actor Loss: 0.0536 VF Loss: 0.0435
# Episode: 290 Timestep: 35917 Total reward: -32.9 Episode length: 135.8 Actor Loss: 0.0375 VF Loss: 0.0788
# Episode: 300 Timestep: 38424 Total reward: -47.3 Episode length: 250.7 Actor Loss: 0.0224 VF Loss: 0.1837
# Episode: 310 Timestep: 40043 Total reward: -37.9 Episode length: 161.9 Actor Loss: -0.0852 VF Loss: 0.0437
# Episode: 320 Timestep: 41637 Total reward: -44.2 Episode length: 159.4 Actor Loss: 0.0165 VF Loss: 0.0497
# Episode: 330 Timestep: 43861 Total reward: -22.1 Episode length: 222.4 Actor Loss: 0.1007 VF Loss: 0.0607
# Episode: 340 Timestep: 49085 Total reward: -31.9 Episode length: 522.4 Actor Loss: 0.1427 VF Loss: 0.1316
# Episode: 350 Timestep: 54525 Total reward: -58.5 Episode length: 544.0 Actor Loss: -0.1038 VF Loss: 0.1360
# Episode: 360 Timestep: 57008 Total reward: -31.0 Episode length: 248.3 Actor Loss: -0.1488 VF Loss: 0.1550
# Episode: 370 Timestep: 59418 Total reward: -23.7 Episode length: 241.0 Actor Loss: 0.0853 VF Loss: 0.1453
# Episode: 380 Timestep: 64565 Total reward: -70.1 Episode length: 514.7 Actor Loss: -0.0531 VF Loss: 0.1852
# Episode: 390 Timestep: 70286 Total reward: -66.9 Episode length: 572.1 Actor Loss: 0.0326 VF Loss: 0.0992
# Episode: 400 Timestep: 78220 Total reward: -97.4 Episode length: 793.4 Actor Loss: 0.1277 VF Loss: 0.1404
# Episode: 410 Timestep: 83388 Total reward: -50.7 Episode length: 516.8 Actor Loss: -0.0496 VF Loss: 0.1061
# Episode: 420 Timestep: 89437 Total reward: -56.0 Episode length: 604.9 Actor Loss: -0.0226 VF Loss: 0.1023
# Episode: 430 Timestep: 94822 Total reward: -44.7 Episode length: 538.5 Actor Loss: -0.0662 VF Loss: 0.2316
# Episode: 440 Timestep: 100579 Total reward: -9.7 Episode length: 575.7 Actor Loss: 0.2027 VF Loss: 0.0989
# Episode: 450 Timestep: 105622 Total reward: -8.9 Episode length: 504.3 Actor Loss: 0.0497 VF Loss: 0.0832
# Episode: 460 Timestep: 111014 Total reward: -25.2 Episode length: 539.2 Actor Loss: -0.0658 VF Loss: 0.0854
# Episode: 470 Timestep: 116987 Total reward: -67.3 Episode length: 597.3 Actor Loss: -0.1405 VF Loss: 0.0960
# Episode: 480 Timestep: 123039 Total reward: -55.4 Episode length: 605.2 Actor Loss: 0.0047 VF Loss: 0.1254
# Episode: 490 Timestep: 129471 Total reward: -36.6 Episode length: 643.2 Actor Loss: 0.0765 VF Loss: 0.1462
# Episode: 500 Timestep: 137679 Total reward: -43.8 Episode length: 820.8 Actor Loss: 0.0837 VF Loss: 0.1090
# Episode: 510 Timestep: 145613 Total reward: -37.3 Episode length: 793.4 Actor Loss: 0.0043 VF Loss: 0.0858
# Episode: 520 Timestep: 155262 Total reward: -42.9 Episode length: 964.9 Actor Loss: -0.0229 VF Loss: 0.0375
# Episode: 530 Timestep: 164247 Total reward: -30.4 Episode length: 898.5 Actor Loss: -0.0528 VF Loss: 0.0390
# Episode: 540 Timestep: 174183 Total reward: -92.5 Episode length: 993.6 Actor Loss: 0.0331 VF Loss: 0.0646
# Episode: 550 Timestep: 182543 Total reward: 8.2 Episode length: 836.0 Actor Loss: 0.0555 VF Loss: 0.0412
# Episode: 560 Timestep: 191788 Total reward: -14.0 Episode length: 924.5 Actor Loss: 0.0059 VF Loss: 0.0215
# Episode: 570 Timestep: 200150 Total reward: -13.5 Episode length: 836.2 Actor Loss: -0.0415 VF Loss: 0.0480
# Episode: 580 Timestep: 208440 Total reward: 21.7 Episode length: 829.0 Actor Loss: 0.0497 VF Loss: 0.0230
# Episode: 590 Timestep: 217210 Total reward: -10.3 Episode length: 877.0 Actor Loss: -0.0060 VF Loss: 0.0401
# Episode: 600 Timestep: 224683 Total reward: 33.6 Episode length: 747.3 Actor Loss: -0.0108 VF Loss: 0.0585
# Episode: 610 Timestep: 229168 Total reward: 0.4 Episode length: 448.5 Actor Loss: -0.1292 VF Loss: 0.1081
# Episode: 620 Timestep: 235003 Total reward: 23.9 Episode length: 583.5 Actor Loss: 0.0738 VF Loss: 0.0592
# Episode: 630 Timestep: 241959 Total reward: -49.7 Episode length: 695.6 Actor Loss: -0.0536 VF Loss: 0.1005
# Episode: 640 Timestep: 251359 Total reward: -35.9 Episode length: 940.0 Actor Loss: 0.0866 VF Loss: 0.0756
# Episode: 650 Timestep: 258896 Total reward: -17.7 Episode length: 753.7 Actor Loss: -0.0222 VF Loss: 0.0548
# Episode: 660 Timestep: 265143 Total reward: 3.6 Episode length: 624.7 Actor Loss: -0.0196 VF Loss: 0.0533
# Episode: 670 Timestep: 267787 Total reward: 1.1 Episode length: 264.4 Actor Loss: -0.0810 VF Loss: 0.0844
# Episode: 680 Timestep: 274834 Total reward: -8.1 Episode length: 704.7 Actor Loss: 0.0485 VF Loss: 0.1228
# Episode: 690 Timestep: 284716 Total reward: -20.0 Episode length: 988.2 Actor Loss: 0.0888 VF Loss: 0.0580
# Episode: 700 Timestep: 291018 Total reward: -8.9 Episode length: 630.2 Actor Loss: -0.0325 VF Loss: 0.1175
# Episode: 710 Timestep: 300184 Total reward: 7.0 Episode length: 916.6 Actor Loss: 0.0714 VF Loss: 0.0369
# Episode: 720 Timestep: 309321 Total reward: -2.9 Episode length: 913.7 Actor Loss: -0.0231 VF Loss: 0.0538
# Episode: 730 Timestep: 318558 Total reward: 24.4 Episode length: 923.7 Actor Loss: -0.0133 VF Loss: 0.0248
# Episode: 740 Timestep: 328215 Total reward: -39.3 Episode length: 965.7 Actor Loss: -0.0360 VF Loss: 0.0538
# Episode: 750 Timestep: 336628 Total reward: 10.0 Episode length: 841.3 Actor Loss: -0.0018 VF Loss: 0.0393
# Episode: 760 Timestep: 345724 Total reward: -19.3 Episode length: 909.6 Actor Loss: 0.0134 VF Loss: 0.0405
# Episode: 770 Timestep: 353299 Total reward: 16.9 Episode length: 757.5 Actor Loss: -0.0137 VF Loss: 0.0492
# Episode: 780 Timestep: 363299 Total reward: 27.6 Episode length: 1000.0 Actor Loss: 0.0621 VF Loss: 0.0256
# Episode: 790 Timestep: 372321 Total reward: 4.1 Episode length: 902.2 Actor Loss: -0.0310 VF Loss: 0.0680
# Episode: 800 Timestep: 381286 Total reward: 2.2 Episode length: 896.5 Actor Loss: -0.0102 VF Loss: 0.0460
# Episode: 810 Timestep: 389703 Total reward: 12.5 Episode length: 841.7 Actor Loss: 0.0054 VF Loss: 0.0507
# Episode: 820 Timestep: 398982 Total reward: 31.7 Episode length: 927.9 Actor Loss: 0.0423 VF Loss: 0.0583
# Episode: 830 Timestep: 406307 Total reward: 40.1 Episode length: 732.5 Actor Loss: -0.0851 VF Loss: 0.0813
# Episode: 840 Timestep: 413011 Total reward: 42.1 Episode length: 670.4 Actor Loss: -0.0682 VF Loss: 0.0657
# Episode: 850 Timestep: 420851 Total reward: -35.5 Episode length: 784.0 Actor Loss: 0.0153 VF Loss: 0.1335
# Episode: 860 Timestep: 430851 Total reward: 15.5 Episode length: 1000.0 Actor Loss: 0.1118 VF Loss: 0.0272
# Episode: 870 Timestep: 440114 Total reward: 48.3 Episode length: 926.3 Actor Loss: -0.0024 VF Loss: 0.0371
# Episode: 880 Timestep: 447715 Total reward: 25.4 Episode length: 760.1 Actor Loss: -0.0662 VF Loss: 0.0591
# Episode: 890 Timestep: 454511 Total reward: 60.0 Episode length: 679.6 Actor Loss: 0.0020 VF Loss: 0.0470
# Episode: 900 Timestep: 461337 Total reward: 14.7 Episode length: 682.6 Actor Loss: -0.0562 VF Loss: 0.1107
# Episode: 910 Timestep: 465560 Total reward: 22.9 Episode length: 422.3 Actor Loss: -0.0680 VF Loss: 0.1825
# Episode: 920 Timestep: 469058 Total reward: 38.4 Episode length: 349.8 Actor Loss: 0.0647 VF Loss: 0.0990
# Episode: 930 Timestep: 474165 Total reward: 57.0 Episode length: 510.7 Actor Loss: 0.1103 VF Loss: 0.0780
# Episode: 940 Timestep: 481693 Total reward: 64.3 Episode length: 752.8 Actor Loss: 0.0021 VF Loss: 0.0563
# Episode: 950 Timestep: 484419 Total reward: 15.6 Episode length: 272.6 Actor Loss: -0.1661 VF Loss: 0.1324
# Episode: 960 Timestep: 487060 Total reward: 8.8 Episode length: 264.1 Actor Loss: -0.0606 VF Loss: 0.1258
# Episode: 970 Timestep: 489265 Total reward: 57.3 Episode length: 220.5 Actor Loss: 0.1340 VF Loss: 0.2299
# Episode: 980 Timestep: 492028 Total reward: 91.3 Episode length: 276.3 Actor Loss: 0.0705 VF Loss: 0.1872
# Episode: 990 Timestep: 496338 Total reward: 31.3 Episode length: 431.0 Actor Loss: -0.0999 VF Loss: 0.2807
# Episode: 1000 Timestep: 502505 Total reward: 44.1 Episode length: 616.7 Actor Loss: -0.0839 VF Loss: 0.0995
# Episode: 1010 Timestep: 511613 Total reward: 17.7 Episode length: 910.8 Actor Loss: 0.0142 VF Loss: 0.0845
# Episode: 1020 Timestep: 519426 Total reward: -19.5 Episode length: 781.3 Actor Loss: 0.0298 VF Loss: 0.2134
# Episode: 1030 Timestep: 529282 Total reward: -1.5 Episode length: 985.6 Actor Loss: 0.0416 VF Loss: 0.0478
# Episode: 1040 Timestep: 536518 Total reward: 65.3 Episode length: 723.6 Actor Loss: 0.0234 VF Loss: 0.1317
# Episode: 1050 Timestep: 542942 Total reward: -35.6 Episode length: 642.4 Actor Loss: -0.0773 VF Loss: 0.1781
# Episode: 1060 Timestep: 548296 Total reward: 59.4 Episode length: 535.4 Actor Loss: 0.0425 VF Loss: 0.1962
# Episode: 1070 Timestep: 555289 Total reward: 3.1 Episode length: 699.3 Actor Loss: 0.0038 VF Loss: 0.1176
# Episode: 1080 Timestep: 561453 Total reward: 75.3 Episode length: 616.4 Actor Loss: -0.0186 VF Loss: 0.1201
# Episode: 1090 Timestep: 568499 Total reward: 98.2 Episode length: 704.6 Actor Loss: -0.0490 VF Loss: 0.1276
# Episode: 1100 Timestep: 576147 Total reward: 47.3 Episode length: 764.8 Actor Loss: -0.0689 VF Loss: 0.0958
# Episode: 1110 Timestep: 582275 Total reward: 29.4 Episode length: 612.8 Actor Loss: -0.0422 VF Loss: 0.1072
# Episode: 1120 Timestep: 590832 Total reward: 29.9 Episode length: 855.7 Actor Loss: 0.0660 VF Loss: 0.0588
# Episode: 1130 Timestep: 599562 Total reward: 71.5 Episode length: 873.0 Actor Loss: 0.0251 VF Loss: 0.0642
# Episode: 1140 Timestep: 607810 Total reward: 70.5 Episode length: 824.8 Actor Loss: -0.0097 VF Loss: 0.0713
# Episode: 1150 Timestep: 616632 Total reward: 53.6 Episode length: 882.2 Actor Loss: -0.0457 VF Loss: 0.0595
# Episode: 1160 Timestep: 622449 Total reward: 130.9 Episode length: 581.7 Actor Loss: 0.0290 VF Loss: 0.1575
# Episode: 1170 Timestep: 629012 Total reward: 157.1 Episode length: 656.3 Actor Loss: 0.0111 VF Loss: 0.1061
# Episode: 1180 Timestep: 635732 Total reward: 101.4 Episode length: 672.0 Actor Loss: -0.0720 VF Loss: 0.0978
# Episode: 1190 Timestep: 642444 Total reward: 36.5 Episode length: 671.2 Actor Loss: -0.0866 VF Loss: 0.1996
# Episode: 1200 Timestep: 648778 Total reward: 120.4 Episode length: 633.4 Actor Loss: 0.0093 VF Loss: 0.1102
# Episode: 1210 Timestep: 653923 Total reward: 92.8 Episode length: 514.5 Actor Loss: -0.0005 VF Loss: 0.1725
# Episode: 1220 Timestep: 660068 Total reward: 88.1 Episode length: 614.5 Actor Loss: 0.0255 VF Loss: 0.1364
# Episode: 1230 Timestep: 664249 Total reward: 123.1 Episode length: 418.1 Actor Loss: 0.0484 VF Loss: 0.1821
# Episode: 1240 Timestep: 669314 Total reward: 130.2 Episode length: 506.5 Actor Loss: 0.0314 VF Loss: 0.1340
# Episode: 1250 Timestep: 673689 Total reward: 137.6 Episode length: 437.5 Actor Loss: -0.1090 VF Loss: 0.1610
# Episode: 1260 Timestep: 678623 Total reward: 129.2 Episode length: 493.4 Actor Loss: -0.0397 VF Loss: 0.1470
# Episode: 1270 Timestep: 684841 Total reward: 140.8 Episode length: 621.8 Actor Loss: 0.0070 VF Loss: 0.1203
# Episode: 1280 Timestep: 691440 Total reward: 88.5 Episode length: 659.9 Actor Loss: -0.0794 VF Loss: 0.1035
# Episode: 1290 Timestep: 699366 Total reward: 89.7 Episode length: 792.6 Actor Loss: -0.0354 VF Loss: 0.0683
# Episode: 1300 Timestep: 707730 Total reward: 11.6 Episode length: 836.4 Actor Loss: -0.0733 VF Loss: 0.0687
# Episode: 1310 Timestep: 715451 Total reward: 135.1 Episode length: 772.1 Actor Loss: 0.0828 VF Loss: 0.0901
# Episode: 1320 Timestep: 722424 Total reward: 133.5 Episode length: 697.3 Actor Loss: -0.0064 VF Loss: 0.0960
# Episode: 1330 Timestep: 729675 Total reward: 105.7 Episode length: 725.1 Actor Loss: -0.0509 VF Loss: 0.1098
# Episode: 1340 Timestep: 736197 Total reward: 143.8 Episode length: 652.2 Actor Loss: 0.0004 VF Loss: 0.1252
# Episode: 1350 Timestep: 742559 Total reward: 178.6 Episode length: 636.2 Actor Loss: 0.0845 VF Loss: 0.1015
# Episode: 1360 Timestep: 747209 Total reward: 85.3 Episode length: 465.0 Actor Loss: -0.1638 VF Loss: 0.1833
# Episode: 1370 Timestep: 752213 Total reward: 143.4 Episode length: 500.4 Actor Loss: -0.0129 VF Loss: 0.1093
# Episode: 1380 Timestep: 753873 Total reward: 47.2 Episode length: 166.0 Actor Loss: -0.0420 VF Loss: 0.1345
# Episode: 1390 Timestep: 755105 Total reward: 29.9 Episode length: 123.2 Actor Loss: -0.0511 VF Loss: 0.1041
# Episode: 1400 Timestep: 756375 Total reward: 22.1 Episode length: 127.0 Actor Loss: -0.0602 VF Loss: 0.0677
# Episode: 1410 Timestep: 757643 Total reward: 14.0 Episode length: 126.8 Actor Loss: -0.0061 VF Loss: 0.1009
# Episode: 1420 Timestep: 761068 Total reward: 122.8 Episode length: 342.5 Actor Loss: 0.2029 VF Loss: 0.3336
# Episode: 1430 Timestep: 763857 Total reward: 22.6 Episode length: 278.9 Actor Loss: -0.1319 VF Loss: 0.2406
# Episode: 1440 Timestep: 768579 Total reward: -11.4 Episode length: 472.2 Actor Loss: -0.0828 VF Loss: 0.1592
# Episode: 1450 Timestep: 777712 Total reward: -114.7 Episode length: 913.3 Actor Loss: -0.0293 VF Loss: 0.0243
# Episode: 1460 Timestep: 787712 Total reward: -93.2 Episode length: 1000.0 Actor Loss: 0.0401 VF Loss: 0.0173
# Episode: 1470 Timestep: 797712 Total reward: -96.1 Episode length: 1000.0 Actor Loss: 0.0054 VF Loss: 0.0098
# Episode: 1480 Timestep: 807712 Total reward: -45.7 Episode length: 1000.0 Actor Loss: 0.0188 VF Loss: 0.0194
# Episode: 1490 Timestep: 817085 Total reward: -49.9 Episode length: 937.3 Actor Loss: -0.0014 VF Loss: 0.0302
# Episode: 1500 Timestep: 826014 Total reward: -0.9 Episode length: 892.9 Actor Loss: 0.0143 VF Loss: 0.0565
# Episode: 1510 Timestep: 831254 Total reward: 132.9 Episode length: 524.0 Actor Loss: 0.0878 VF Loss: 0.1415
# Episode: 1520 Timestep: 837778 Total reward: 157.2 Episode length: 652.4 Actor Loss: 0.0815 VF Loss: 0.1088
# Stopping at episode 1524 with average rewards of 190.01132834959066 in last 10 episodes

# %%
from google.colab import files

# plot stats
def get_running_stat(stat, stat_len):
    cum_sum = np.cumsum(np.insert(stat, 0, 0)) 
    return (cum_sum[stat_len:] - cum_sum[:-stat_len]) / stat_len

episode, r, l = np.array(stats_rewards_list).T
cum_r = get_running_stat(r, 10)
cum_l = get_running_stat(l, 10)

# plot rewards
plt.plot(episode[-len(cum_r):], cum_r)
plt.plot(episode, r, alpha=0.5)
plt.xlabel('Episode')
plt.ylabel('Episode Reward')
plt.savefig(fname="PG.png")
files.download("PG.png")

# %%
# plot episode lengths
plt.plot(episode[-len(cum_l):], cum_l)
plt.plot(episode, l, alpha=0.5)
plt.xlabel('Episode')
plt.ylabel('Episode Length')
# Out:
# Text(0, 0.5, 'Episode Length')
